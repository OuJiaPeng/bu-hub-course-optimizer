# %% [markdown]
# w

# %%
import os
import pandas as pd
from pulp import LpProblem, LpVariable, lpSum, LpMinimize, LpBinary, LpStatus, value, PULP_CBC_CMD

# %%
# load data
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
DATA_PATH = os.path.join(ROOT_DIR, "data", "Vectorized_BU_Hub_Courses.csv")

vectorized_df = pd.read_csv(DATA_PATH)
vectorized_df.columns = vectorized_df.columns.str.strip()

# # Entire HUB requirement
# requirement_counts = {
#     'Philosophical Inquiry and Life’s Meanings': 1,
#     'Aesthetic Exploration': 1,
#     'Historical Consciousness': 1,
#     'Social Inquiry I': 1,
#     'Social Inquiry II': 1,
#     'Scientific Inquiry I': 1,
#     'Scientific Inquiry II': 1,
#     'Quantitative Reasoning I': 1,
#     'Quantitative Reasoning II': 1,
#     'First-Year Writing Seminar': 1,
#     'Writing-Intensive Course': 2,
#     'Writing, Research, and Inquiry': 1,
#     'Oral and/or Signed Communication': 1,
#     'Digital/Multimedia Expression': 1,
#     'Critical Thinking': 2,
#     'Research and Information Literacy': 2,
#     'Teamwork / Collaboration': 2,
#     'Creativity / Innovation': 2,
#     'The Individual in Community': 1,
#     'Global Citizenship and Intercultural Literacy': 2,
#     'Ethical Reasoning': 1
# }

# specific requirements
requirement_counts = {
    'Philosophical Inquiry and Life’s Meanings': 1,
    'Aesthetic Exploration': 1,
    'Historical Consciousness': 1,
    'Social Inquiry I': 0,
    'Social Inquiry II': 0,
    'Scientific Inquiry I': 0,
    'Scientific Inquiry II': 0,
    'Quantitative Reasoning I': 0,
    'Quantitative Reasoning II': 0,
    'First-Year Writing Seminar': 0,
    'Writing-Intensive Course': 1,
    'Writing, Research, and Inquiry': 0,
    'Oral and/or Signed Communication': 0,
    'Digital/Multimedia Expression': 0,
    'Critical Thinking': 0,
    'Research and Information Literacy': 0,
    'Teamwork / Collaboration': 1,
    'Creativity / Innovation': 0,
    'The Individual in Community': 1,
    'Global Citizenship and Intercultural Literacy': 1,
    'Ethical Reasoning': 1
}

# filters (edit as you please)
excluded_colleges = ['CGS', 'SAR', 'QST']   # e.g. exclude CGS, SAR, QST
excluded_departments = ['BI', 'PY']         # exclude department codes like BI = Biology, PY = Physics
excluded_course_codes = ['CAS WR 153E']     # specific courses to remove
excluded_keywords = ['Summer', 'Analysis']  # keyword-based filters

# apply filters
vectorized_df = vectorized_df[
    ~vectorized_df['Course Code'].str.extract(r'([A-Z]+)', expand=False).isin(excluded_colleges) &
    ~vectorized_df['Course Code'].str.extract(r'[A-Z]+\s+([A-Z]+)', expand=False).isin(excluded_departments) &
    ~vectorized_df['Course Code'].isin(excluded_course_codes) &
    ~vectorized_df['Course Title'].str.contains('|'.join(excluded_keywords), case=False, na=False)
].reset_index(drop=True)

# %%
# setup and single solution. for more, look next cell.

# setup
hub_columns = [col for col in vectorized_df.columns if col in requirement_counts]
A = vectorized_df[hub_columns].values
b = [requirement_counts[col] for col in hub_columns]
courses = vectorized_df["Course Code"] + " - " + vectorized_df["Course Title"]

# unique course key: department & number (e.g. CAS WR 153)
vectorized_df["Course Key"] = vectorized_df["Course Code"].str.extract(r'([A-Z]+\s+\w+)', expand=False)
course_keys = vectorized_df["Course Key"]
course_key_to_indices = {}
for idx, key in enumerate(course_keys):
    course_key_to_indices.setdefault(key, []).append(idx)

# problem setup
prob = LpProblem("BU_Hub_Course_Selection", LpMinimize)
x = [LpVariable(f"x_{i}", cat=LpBinary) for i in range(len(courses))]

prob += lpSum(x)

# constraints (satisfy each given hub requirement)
for j, req in enumerate(hub_columns):
    prob += lpSum(A[i][j] * x[i] for i in range(len(courses))) >= b[j], f"Requirement_{req}"

# constraint (prevent duplicate department-courses)
for key, indices in course_key_to_indices.items():
    if len(indices) > 1:
        prob += lpSum(x[i] for i in indices) <= 1, f"Unique_{key}"

# solve (thanks PuLP)
prob.solve(PULP_CBC_CMD(msg=0))

# results
selected_courses = [courses[i] for i in range(len(courses)) if x[i].varValue == 1]
print(f"Number of courses selected: {len(selected_courses)}")
print("Courses:")
for course in selected_courses:
    print("-", course)
# Out:
# Number of courses selected: 3
# Courses:
# - CAS AH 333 - Arts of Classical Greece
# - CAS PH 245S - PHIL & RELIGION
# - CAS JS 100 - World Cultures of the Jews

# %%
# store the first solution
found_solutions = [set(i for i in range(len(x)) if x[i].varValue == 1)]

print("Solution 1:")
for i in found_solutions[0]:
    print("-", courses[i])
print("-----")

# loop to find more (limit set at 100, change to your liking)
while len(found_solutions) < 100:
    # constraint to block the last solution
    prob += lpSum([x[i] for i in found_solutions[-1]]) <= len(found_solutions[-1]) - 1

    # solve again
    prob.solve(PULP_CBC_CMD(msg=0))

    if LpStatus[prob.status] != 'Optimal':
        print("No more feasible solutions.")
        break

    # save new solution
    new_solution = set(i for i in range(len(x)) if x[i].varValue == 1)

    # print solution
    print(f"Solution {len(found_solutions) + 1}:")
    for i in new_solution:
        print("-", courses[i])
    print("-----")

    # add to list of found solutions
    found_solutions.append(new_solution)
# Out:
# Solution 1:
# - CAS JS 100 - World Cultures of the Jews
# - CAS AH 333 - Arts of Classical Greece
# - CAS PH 245S - PHIL & RELIGION
# -----
# Solution 2:
# - CAS CC 202 - Core Humanities 4: Enlightenment, Romanticism, and Modernity
# - CAS HI 190 - History of Boston: Community and Conflict
# - HUB SA 301E - KYOTO ELCTV 1
# -----
# Solution 3:
# - CAS AR 333 - Arts of Classical Greece
# - CAS IR 337S - Religion and Politics
# - WED ED 200 - Introduction to Justice-Based Education
# -----
# Solution 4:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS HI 299S - Civil Rights History
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 5:
# - CAS AA 310 - Civil Rights History
# - CAS PO 596 - Colonization/Decolonization
# - HUB SA 301E - KYOTO ELCTV 1
# -----
# Solution 6:
# - CAS AH 333 - Arts of Classical Greece
# - CAS PH 496 - Topics in Religious Thought
# - CAS RN 766 - Religion and the Problem of Tolerance
# -----
# Solution 7:
# - CAS RN 245 - The Quest for God and the Good
# - CAS AH 333 - Arts of Classical Greece
# - CAS JS 379 - Islamophobia and Antisemitism
# -----
# Solution 8:
# - CAS EN 177 - Introduction to Asian-American Literature
# - CAS AH 333 - Arts of Classical Greece
# - CAS RN 752 - Topics in Religious Thought
# -----
# Solution 9:
# - WED HD 331 - African American School Achievement
# - CAS AH 333 - Arts of Classical Greece
# - CAS RN 452 - Topics in Religious Thought
# -----
# Solution 10:
# - CAS RN 338 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS HI 299 - Civil Rights History
# - CAS AH 333 - Arts of Classical Greece
# -----
# Solution 11:
# - CAS RN 246 - S24: Sex, Death, and the Buddha
# - CAS AH 333 - Arts of Classical Greece
# - CAS AN 302 - Transforming Life: Anthropology of Gender and Medical Technologies
# -----
# Solution 12:
# - CAS AA 310S - History of the Civil Rights Movement
# - CAS PH 245 - The Quest for God and the Good
# - CAS AR 333 - Arts of Classical Greece
# -----
# Solution 13:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS EN 128S - Representing Boston
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 14:
# - CAS PO 379S - Religion and Politics
# - CAS AR 333 - Arts of Classical Greece
# - CAS RN 638 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# -----
# Solution 15:
# - CAS AR 333 - Arts of Classical Greece
# - CAS EN 128 - Representing Boston
# - CAS PH 495 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# -----
# Solution 16:
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# - CAS RN 214 - Islam
# -----
# Solution 17:
# - CAS RN 466 - Religion and the Problem of Tolerance
# - CAS JS 348 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - HUB SA 301E - KYOTO ELCTV 1
# -----
# Solution 18:
# - WED CE 342 - Anti-Oppressive Practice: Education & Applied Psychology
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 19:
# - CAS LX 691 - Linguistic Field Methods
# - WED ED 200 - Introduction to Justice-Based Education
# - HUB SA 301E - KYOTO ELCTV 1
# -----
# Solution 20:
# - CAS AR 333 - Arts of Classical Greece
# - CAS RN 452 - Topics in Religious Thought
# - CAS PO 379 - Religion and Politics
# -----
# Solution 21:
# - CAS RN 249 - Islamophobia and Antisemitism
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 22:
# - CAS RN 246 - S24: Sex, Death, and the Buddha
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 23:
# - CAS AR 333 - Arts of Classical Greece
# - CAS HI 227 - Living in the City
# - WED ED 200 - Introduction to Justice-Based Education
# -----
# Solution 24:
# - CAS CL 224S - GREEK DRAMA
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CI 283S - Arab Cultures Through Film (in English translation)
# -----
# Solution 25:
# - CAS IR 337 - Religion and Politics
# - CAS JS 348 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS AH 333 - Arts of Classical Greece
# -----
# Solution 26:
# - CAS CC 202 - Core Humanities 4: Enlightenment, Romanticism, and Modernity
# - CAS RN 466 - Religion and the Problem of Tolerance
# - HUB SA 301E - KYOTO ELCTV 1
# -----
# Solution 27:
# - CAS AH 333 - Arts of Classical Greece
# - CAS EN 128 - Representing Boston
# - CAS RN 638 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# -----
# Solution 28:
# - CAS RN 338 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS AH 333 - Arts of Classical Greece
# - CAS LX 331 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# -----
# Solution 29:
# - CAS JS 348 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS AR 333 - Arts of Classical Greece
# - CAS HI 299 - Civil Rights History
# -----
# Solution 30:
# - WED HD 331 - African American School Achievement
# - CAS AR 333 - Arts of Classical Greece
# - CAS JS 348 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# -----
# Solution 31:
# - CAS HI 299 - Civil Rights History
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 32:
# - CAS LX 631 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# - CAS AR 333 - Arts of Classical Greece
# - CAS JS 348 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# -----
# Solution 33:
# - CAS LR 355 - Chekhov: The Stories and Plays (in English translation)
# - CAS AR 333 - Arts of Classical Greece
# - CAS LS 309 - Spanish for Heritage and Native Speakers
# -----
# Solution 34:
# - CAS PO 596 - Colonization/Decolonization
# - CAS HI 299 - Civil Rights History
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 35:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS RN 249 - Islamophobia and Antisemitism
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 36:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - WED DE 300 - Introduction to the Deaf World
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 37:
# - CAS AH 333 - Arts of Classical Greece
# - WED DE 350 - Deaf History and Culture
# - WED ED 200 - Introduction to Justice-Based Education
# -----
# Solution 38:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS RN 379 - Religion and Politics
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 39:
# - CAS RN 246 - S24: Sex, Death, and the Buddha
# - CAS LS 309E - Composition for Native Speakers of Spanish
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 40:
# - CAS RN 246 - S24: Sex, Death, and the Buddha
# - CAS CG 105E - BUPH SUM LNG
# - CAS EN 562 - Studies in Asexualities
# -----
# Solution 41:
# - CAS IR 352S - International Human Rights
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 42:
# - CAS CL 224 - Greek Drama in Translation
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 43:
# - CAS PO 378S - International Human Rights
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 44:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS RN 379S - Religion and Politics
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 45:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS HI 299 - Civil Rights History
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 46:
# - CAS RN 246 - S24: Sex, Death, and the Buddha
# - CAS WS 562 - Studies in Asexualities
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 47:
# - CAS LY 283 - Arab Cultures Through Film (in English translation)
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS LG 463 - German Theatre
# -----
# Solution 48:
# - CAS AH 333 - Arts of Classical Greece
# - CAS AN 302 - Transforming Life: Anthropology of Gender and Medical Technologies
# - CAS RN 664 - Buddhist Literature
# -----
# Solution 49:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS RN 766 - Religion and the Problem of Tolerance
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 50:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS EN 128S - Representing Boston
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 51:
# - CAS JS 379 - Islamophobia and Antisemitism
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 52:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS LX 631 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 53:
# - CAS EC 371S - Environmental Economics
# - WED ED 200 - Introduction to Justice-Based Education
# - HUB SA 301E - KYOTO ELCTV 1
# -----
# Solution 54:
# - CAS EN 177 - Introduction to Asian-American Literature
# - CAS CG 105E - BUPH SUM LNG
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 55:
# - CAS AR 333 - Arts of Classical Greece
# - CAS JS 100 - World Cultures of the Jews
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 56:
# - CAS RN 245 - The Quest for God and the Good
# - CAS AR 333 - Arts of Classical Greece
# - CAS JS 100 - World Cultures of the Jews
# -----
# Solution 57:
# - CAS PO 596 - Colonization/Decolonization
# - CAS HI 190 - History of Boston: Community and Conflict
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 58:
# - CAS AA 310 - Civil Rights History
# - CAS PO 596 - Colonization/Decolonization
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 59:
# - CAS JS 100 - World Cultures of the Jews
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 60:
# - CAS PO 378 - International Human Rights: Applying Human Rights in Africa
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 61:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS JS 100 - World Cultures of the Jews
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 62:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS AH 333 - Arts of Classical Greece
# - CAS JS 100 - World Cultures of the Jews
# -----
# Solution 63:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS AH 333 - Arts of Classical Greece
# - WED DE 300 - Introduction to the Deaf World
# -----
# Solution 64:
# - CAS PO 379S - Religion and Politics
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS AH 333 - Arts of Classical Greece
# -----
# Solution 65:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS AH 333 - Arts of Classical Greece
# - WED DE 350 - Deaf History and Culture
# -----
# Solution 66:
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS CG 105E - BUPH SUM LNG
# - CAS LX 331 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# -----
# Solution 67:
# - CAS LX 391 - Linguistic Field Methods
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 68:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS RN 379 - Religion and Politics
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 69:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS HI 190 - History of Boston: Community and Conflict
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 70:
# - CAS IR 352 - International Human Rights: Applying Human Rights in Africa
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 71:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS CG 105E - BUPH SUM LNG
# - CAS LX 331 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# -----
# Solution 72:
# - CAS LX 631 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# - CAS AR 333 - Arts of Classical Greece
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 73:
# - CAS EN 177 - Introduction to Asian-American Literature
# - CAS AN 311 - Culture and Biotech: Beyond the Nature/Culture Divide
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 74:
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# - CAS XL 244 - Greek Drama in Translation
# -----
# Solution 75:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS EN 128 - Representing Boston
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 76:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - WED DE 350 - Deaf History and Culture
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 77:
# - CAS AA 310 - Civil Rights History
# - CAS CG 105E - BUPH SUM LNG
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 78:
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS HI 299S - Civil Rights History
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 79:
# - CAS JS 348 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS EN 128 - Representing Boston
# - CAS LG 463 - German Theatre
# -----
# Solution 80:
# - CAS AR 333 - Arts of Classical Greece
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS LX 331 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# -----
# Solution 81:
# - CAS EC 371 - Environmental Economics
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 82:
# - CAS AH 325 - Art, Media, and Buddhism
# - CAS LX 631 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 83:
# - CAS LX 631 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# - CAS AR 333 - Arts of Classical Greece
# - WED ED 200 - Introduction to Justice-Based Education
# -----
# Solution 84:
# - CAS AR 333 - Arts of Classical Greece
# - WED DE 350 - Deaf History and Culture
# - WED ED 200 - Introduction to Justice-Based Education
# -----
# Solution 85:
# - CAS AR 331 - Early Greek Art and Architecture
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# - CAS LX 331 - Semantics & Pragmatics: Introduction to Linguistic Meaning
# -----
# Solution 86:
# - CAS JS 367 - The Holocaust Through Film
# - CAS EN 177 - Introduction to Asian-American Literature
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 87:
# - CAS RN 245 - The Quest for God and the Good
# - CAS AA 310 - Civil Rights History
# - CAS AR 333 - Arts of Classical Greece
# -----
# Solution 88:
# - CAS RN 245 - The Quest for God and the Good
# - CAS EN 177 - Introduction to Asian-American Literature
# - CAS AR 333 - Arts of Classical Greece
# -----
# Solution 89:
# - CAS PO 596 - Colonization/Decolonization
# - CAS RN 379 - Religion and Politics
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 90:
# - CAS AR 333 - Arts of Classical Greece
# - CAS RN 364 - Buddhist Literature
# - CAS LS 309 - Spanish for Heritage and Native Speakers
# -----
# Solution 91:
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS LF 487 - Topics in Memory & Monument
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 92:
# - CAS LF 687 - Topics in Memory & Monument
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 93:
# - CAS RN 766 - Religion and the Problem of Tolerance
# - WED ED 200 - Introduction to Justice-Based Education
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 94:
# - CAS LS 462 - Mexican Cinema on the World Stage
# - CAS JS 100 - World Cultures of the Jews
# - CAS CL 303 - The Decline and Fall of the Roman Empire
# -----
# Solution 95:
# - CAS JS 100 - World Cultures of the Jews
# - CAS AH 333 - Arts of Classical Greece
# - WED ED 200 - Introduction to Justice-Based Education
# -----
# Solution 96:
# - CAS JS 379 - Islamophobia and Antisemitism
# - CAS RN 338 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS AH 333 - Arts of Classical Greece
# -----
# Solution 97:
# - CAS JS 379 - Islamophobia and Antisemitism
# - CAS RN 338 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 98:
# - CAS EN 177 - Introduction to Asian-American Literature
# - CAS PO 596 - Colonization/Decolonization
# - CAS CG 105E - BUPH SUM LNG
# -----
# Solution 99:
# - CAS RN 245 - The Quest for God and the Good
# - CAS HI 190 - History of Boston: Community and Conflict
# - CAS EN 230 - Environmental Humanities and Society
# -----
# Solution 100:
# - CAS AR 333 - Arts of Classical Greece
# - CAS HI 190 - History of Boston: Community and Conflict
# - CAS PH 495 - Philosophy and Mysticism: Jewish and Islamic Perspectives
# -----
